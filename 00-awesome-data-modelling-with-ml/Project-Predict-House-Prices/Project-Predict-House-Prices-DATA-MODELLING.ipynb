# %% [markdown]
# # Project Objective: Training and optimizing AI model to predict the Housing Prices

# %% [markdown]
# ## Module 1: DATA COLLECTION

# %% [markdown]
# #### Step 1.1 Import the required libraries

# %%
import pandas as pd

# %% [markdown]
# #### Step 1.2 Load the Data as a DataFrame

# %%
houses = pd.read_excel('Dataset-1.xlsx')

# %% [markdown]
# ## Module 2: DATA EXPLORATION

# %% [markdown]
# ### Step 2.1 Data Inspection - head(), info(), describe() etc.

# %%
houses.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.25     37.85                  52         1627           280.0
# 3    -122.25     37.85                  52          919           213.0
# 4    -122.25     37.84                  52         2535           489.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         565         259         3.8462              342200        NEAR BAY
# 3         413         193         4.0368              269700        NEAR BAY
# 4        1094         514         3.6591              299200        NEAR BAY

# %%
houses.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  18565.000000  18565.000000        18565.000000  18565.000000
# mean    -119.570116     35.633888           28.615890   2634.033827
# std        2.002922      2.137014           12.564224   2195.915548
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1442.000000
# 50%     -118.500000     34.260000           29.000000   2123.000000
# 75%     -118.010000     37.710000           37.000000   3141.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    18376.000000  18565.000000  18565.000000   18565.000000
# mean       537.711199   1426.223108    499.450902       3.867012
# std        424.125849   1142.570832    384.553175       1.895988
# min          2.000000      3.000000      2.000000       0.499900
# ...

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18565 entries, 0 to 18564
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           18565 non-null  float64
#  1   latitude            18565 non-null  float64
#  2   housing_median_age  18565 non-null  int64
#  3   total_rooms         18565 non-null  int64
#  4   total_bedrooms      18376 non-null  float64
#  5   population          18565 non-null  int64
#  6   households          18565 non-null  int64
#  7   median_income       18565 non-null  float64
#  8   median_house_value  18565 non-null  int64
#  9   ocean_proximity     18565 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Step 2.2 Data Aggregation - value_counts(), mean(), groupby()

# %% [markdown]
# ### Step 2.3 Data Cleaning - Handle missing values, duplicates, inconsistent formats, etc.

# %% [markdown]
# ### Step 2.4 Data Storage - Save the cleaned data for future use.

# %% [markdown]
# ## Module 3: DATA VISUALIZATION

# %% [markdown]
# ### ** *Because certain data patterns are only understood when represented with a visualization*

# %%
# Unique values of ocean proximity
sorted(houses['ocean_proximity'].unique())
# Out:
# ['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']

# %% [markdown]
# ### Distribution Visualization

# %% [markdown]
# #### Histogram of Median House Value

# %%
houses[['median_house_value']].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### Histogram of Median Income

# %%
houses[['median_income']].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### Histogram of Housing Median Age

# %%
houses[['housing_median_age']].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Comparision Visualization

# %% [markdown]
# #### Median Income vs. Median House Value

# %%
houses.plot(kind = 'scatter', x = 'median_income', y = 'median_house_value')
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %% [markdown]
# #### Population vs. Median House Value

# %%
houses.plot(kind = 'scatter', x = 'population', y = 'median_house_value')
# Out:
# <Axes: xlabel='population', ylabel='median_house_value'>

# %% [markdown]
# #### Longitude vs. Latitude colored by House Value (Geo Scatter Plot)

# %%
sorted(houses['ocean_proximity'].unique())
# Out:
# ['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']

# %%
houses.pivot(columns = 'ocean_proximity', values = 'longitude').plot(kind='box',figsize = (10,6))
# Out:
# <Axes: >

# %%
houses.pivot(columns = 'ocean_proximity', values = 'latitude').plot(kind='box',figsize = (10,6))
# Out:
# <Axes: >

# %% [markdown]
# #### Count of houses by ocean proximity

# %% [markdown]
# ## Module 4: DATA MODELLING

# %% [markdown]
# ## Module 5: DATA OPTIMIZATION
