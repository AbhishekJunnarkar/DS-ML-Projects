# %%
import numpy as np   # Some basic libraries
import pandas as pd
import matplotlib.pyplot as plt  #A visvualization library
from sklearn.neural_network import MLPRegressor  #Importing MLP from sklearn
from math import sqrt                      #Some libraries for error calculation
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split  #Split the data set
from sklearn import preprocessing  #preprocessing library

# %%
#columns name 
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
#Data load from csv file
df = pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=column_names)
df.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
print('Name of columns', df.columns,'\nShape of data', np.shape(df))
# Out:
# Name of columns Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')
# Shape of data (506, 14)

# %%
#A brief statistical details
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
#Select all columns (except MEDV) as input features set
X = df.drop(['MEDV'], axis=1)
print('Shape of input feature:',X.shape)
#Preprocessing is done
X = preprocessing.scale(X)
# Out:
# Shape of input feature: (506, 13)

# %%
#Select the target variable
Y=df['MEDV']
print('Shape of target:', Y.shape)
# Out:
# Shape of target: (506,)

# %%
#The actual data is splited into test and train datasets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
#The MLP algorithm with some hyperparameters
model = MLPRegressor(hidden_layer_sizes=[20,20],activation='relu',alpha=1.0,
                   learning_rate ='constant', max_iter=10000,random_state=42)
#Model is trained on training dataset
model.fit(X_train,y_train)
# Out:
# MLPRegressor(alpha=1.0, hidden_layer_sizes=[20, 20], max_iter=10000,
#              random_state=42)

# %%
#Predictions are done on input test and train
y_predtest = model.predict(X_test)
y_predtrain = model.predict(X_train)

# %%
#A scatter plot with a metric r_square
plt.figure(figsize = (8,8))
plt.plot([0,60],[0,60],color='black')
plt.scatter(y_test,y_predtest , s=35, color='red',marker='>',label='Test $R^{2}$=''%.3f'%r2_score(y_test,y_predtest),alpha=1)
plt.scatter(y_train, y_predtrain,    s=35, color='blue',marker='o',label='Train $R^{2}$=''%.3f'%r2_score(y_train,y_predtrain),alpha=1 )

plt.xlim(0,60)
plt.ylim(0,60)
plt.legend(frameon=False,prop={'weight':'bold'})
plt.xlabel('Measured MEDV',fontweight='bold')
plt.ylabel('Predicted MEDV',fontweight='bold')
plt.title('MLP Regression',fontweight='bold')
plt.axis('square')

#plt.savefig('MLP_1.pdf', dpi=5000)  # Save the plot in pdf
plt.show()

# %%
#Some important metrics for our trained model for train and test set
print('parameter for train')
print('mean_squared_error:', mean_squared_error(y_train,y_predtrain))
print('mean_absolute_error:',mean_absolute_error(y_train,y_predtrain))
print('root mean squared error:', sqrt(mean_squared_error(y_train,y_predtrain)))
print('MPAE:',np.mean(np.abs((y_train - y_predtrain) / y_train)) * 100)
print('\nR2 value_train:',r2_score(y_train,y_predtrain))

print('\nparameter for testing')
print('mean_squared_error:', mean_squared_error(y_test,y_predtest))
print('mean_absolute_error:',mean_absolute_error(y_test,y_predtest))
print('root mean squared error:', sqrt(mean_squared_error(y_test,y_predtest)))
print('MPAE:',np.mean(np.abs((y_test - y_predtest) / y_test)) * 100)
print('\nR2 value_test:',r2_score(y_test,y_predtest))
# Out:
# parameter for train
# mean_squared_error: 1.555330264177448
# mean_absolute_error: 0.8859098938658653
# root mean squared error: 1.2471288081739784
# MPAE: 4.554623914166758
#
# R2 value_train: 0.9808431061776824
#
# parameter for testing
# mean_squared_error: 18.719751214678908
# mean_absolute_error: 2.6913276793627032
# root mean squared error: 4.326632780197426
# MPAE: 15.23699693095837
#
# R2 value_test: 0.7957573949010603

# %% [markdown]
# **Nerual network by using keras framework**

# %%
#Import some crucial tools from tensorflow library
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Dropout,Dense
from tensorflow.keras import Sequential

# %%
#The weight initiatization is fixed
import random
random.seed(11)

# %%
#A custom metric r_square is defined
def r_square(y_test, y_predtest):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_test - y_predtest)) 
    SS_tot = K.sum(K.square(y_test - K.mean(y_test))) 
    return (1 - (SS_res)/(SS_tot))

# %%
#Architcture of NN with dropout layer
def create_model():
    model = Sequential()
    model.add(Dense(400, input_dim=13, activation='relu'))
    model.add(Dropout(0.20))
    model.add(Dense(400, activation='relu'))
    model.add(Dropout(0.20))
    model.add(Dense(400, activation='relu'))
    model.add(Dropout(0.20))
    model.add(Dense(300, activation='relu'))
    model.add(Dropout(0.20))
    model.add(Dense(1))
    # Compile model
    sgd = keras.optimizers.SGD(learning_rate=0.001)
    model.compile(loss = tf.keras.losses.MeanSquaredError(), optimizer=sgd, metrics = [r_square])
    #adam=keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    #model.compile(loss = tf.keras.losses.MeanSquaredError(), optimizer=adam, metrics = [r_square])
    return model
#Model is called here
model=create_model()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.SGD`.

# %%
model = model.fit(X_train, # Features
                      y_train, # Target vector
                      epochs = 100,
                      verbose = 1,
                      validation_split = 0.2) # Data for evaluation
# Out:
# Epoch 1/100
# 1/9 [==>...........................] - ETA: 1s - loss: 703.3416 - r_square: -5.7346
# 2025-06-22 08:12:09.915043: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 9/9 [==============================] - 0s 8ms/step - loss: 488.2103 - r_square: -5.4980 - val_loss: 132.1037 - val_r_square: -0.6321
# Epoch 2/100
# 9/9 [==============================] - 0s 2ms/step - loss: 69.1824 - r_square: 0.0900 - val_loss: 38.3313 - val_r_square: 0.5541
# Epoch 3/100
# 9/9 [==============================] - 0s 3ms/step - loss: 36.7625 - r_square: 0.5350 - val_loss: 27.3441 - val_r_square: 0.6950
# Epoch 4/100
# 9/9 [==============================] - 0s 2ms/step - loss: 36.7211 - r_square: 0.5072 - val_loss: 30.2530 - val_r_square: 0.6601
# Epoch 5/100
# 9/9 [==============================] - 0s 2ms/step - loss: 31.2552 - r_square: 0.5614 - val_loss: 23.8923 - val_r_square: 0.7210
# Epoch 6/100
# 9/9 [==============================] - 0s 2ms/step - loss: 23.9201 - r_square: 0.6990 - val_loss: 21.5237 - val_r_square: 0.7529
# Epoch 7/100
# 9/9 [==============================] - 0s 2ms/step - loss: 25.8764 - r_square: 0.6423 - val_loss: 21.3738 - val_r_square: 0.7678
# Epoch 8/100
# 9/9 [==============================] - 0s 2ms/step - loss: 29.1910 - r_square: 0.6464 - val_loss: 22.8627 - val_r_square: 0.7496
# Epoch 9/100
# 9/9 [==============================] - 0s 2ms/step - loss: 27.3653 - r_square: 0.6603 - val_loss: 20.1332 - val_r_square: 0.7502
# Epoch 10/100
# 9/9 [==============================] - 0s 2ms/step - loss: 24.8465 - r_square: 0.6747 - val_loss: 21.9658 - val_r_square: 0.7504
# Epoch 11/100
# 9/9 [==============================] - 0s 2ms/step - loss: 21.8793 - r_square: 0.7228 - val_loss: 20.3680 - val_r_square: 0.7697
# Epoch 12/100
# 9/9 [==============================] - 0s 2ms/step - loss: 23.3393 - r_square: 0.6999 - val_loss: 22.3198 - val_r_square: 0.7493
# Epoch 13/100
# 9/9 [==============================] - 0s 2ms/step - loss: 21.8194 - r_square: 0.7135 - val_loss: 23.6060 - val_r_square: 0.7338
# Epoch 14/100
# 9/9 [==============================] - 0s 2ms/step - loss: 21.7941 - r_square: 0.6845 - val_loss: 22.1517 - val_r_square: 0.7048
# Epoch 15/100
# 9/9 [==============================] - 0s 2ms/step - loss: 21.1121 - r_square: 0.6985 - val_loss: 18.8976 - val_r_square: 0.7877
# Epoch 16/100
# 9/9 [==============================] - 0s 2ms/step - loss: 17.5772 - r_square: 0.7695 - val_loss: 17.9283 - val_r_square: 0.8062
# Epoch 17/100
# 9/9 [==============================] - 0s 2ms/step - loss: 22.6417 - r_square: 0.7137 - val_loss: 30.7362 - val_r_square: 0.5917
# Epoch 18/100
# 9/9 [==============================] - 0s 2ms/step - loss: 29.5515 - r_square: 0.5943 - val_loss: 22.0174 - val_r_square: 0.7120
# Epoch 19/100
# 9/9 [==============================] - 0s 2ms/step - loss: 18.9674 - r_square: 0.7428 - val_loss: 16.4341 - val_r_square: 0.8086
# Epoch 20/100
# 9/9 [==============================] - 0s 2ms/step - loss: 16.7093 - r_square: 0.7950 - val_loss: 16.6150 - val_r_square: 0.8125
# Epoch 21/100
# 9/9 [==============================] - 0s 2ms/step - loss: 19.7037 - r_square: 0.7225 - val_loss: 16.6841 - val_r_square: 0.8069
# Epoch 22/100
# 9/9 [==============================] - 0s 2ms/step - loss: 18.3070 - r_square: 0.7698 - val_loss: 32.5822 - val_r_square: 0.5335
# Epoch 23/100
# 9/9 [==============================] - 0s 3ms/step - loss: 21.5427 - r_square: 0.6882 - val_loss: 17.9508 - val_r_square: 0.8067
# Epoch 24/100
# 9/9 [==============================] - 0s 2ms/step - loss: 19.5040 - r_square: 0.7413 - val_loss: 15.3011 - val_r_square: 0.8294
# Epoch 25/100
# 9/9 [==============================] - 0s 2ms/step - loss: 16.0456 - r_square: 0.7949 - val_loss: 14.5641 - val_r_square: 0.8269
# Epoch 26/100
# 9/9 [==============================] - 0s 3ms/step - loss: 21.3802 - r_square: 0.6907 - val_loss: 15.3521 - val_r_square: 0.8284
# Epoch 27/100
# 9/9 [==============================] - 0s 2ms/step - loss: 18.4150 - r_square: 0.7631 - val_loss: 23.2558 - val_r_square: 0.7158
# Epoch 28/100
# 9/9 [==============================] - 0s 2ms/step - loss: 16.8404 - r_square: 0.7764 - val_loss: 14.8850 - val_r_square: 0.8227
# Epoch 29/100
# 9/9 [==============================] - 0s 2ms/step - loss: 18.4804 - r_square: 0.7152 - val_loss: 14.8625 - val_r_square: 0.8277
# Epoch 30/100
# 9/9 [==============================] - 0s 3ms/step - loss: 18.0897 - r_square: 0.7678 - val_loss: 15.2833 - val_r_square: 0.8240
# Epoch 31/100
# 9/9 [==============================] - 0s 3ms/step - loss: 14.7815 - r_square: 0.7963 - val_loss: 19.6824 - val_r_square: 0.7677
# Epoch 32/100
# 9/9 [==============================] - 0s 2ms/step - loss: 17.1323 - r_square: 0.7372 - val_loss: 19.8822 - val_r_square: 0.7876
# Epoch 33/100
# 9/9 [==============================] - 0s 3ms/step - loss: 20.2894 - r_square: 0.7363 - val_loss: 20.3593 - val_r_square: 0.7661
# Epoch 34/100
# 9/9 [==============================] - 0s 3ms/step - loss: 18.9169 - r_square: 0.7572 - val_loss: 14.8896 - val_r_square: 0.8323
# Epoch 35/100
# 9/9 [==============================] - 0s 3ms/step - loss: 15.5864 - r_square: 0.7879 - val_loss: 14.7885 - val_r_square: 0.8267
# Epoch 36/100
# 9/9 [==============================] - 0s 2ms/step - loss: 13.8288 - r_square: 0.7984 - val_loss: 15.7172 - val_r_square: 0.8191
# Epoch 37/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.7110 - r_square: 0.8533 - val_loss: 20.4798 - val_r_square: 0.7512
# Epoch 38/100
# 9/9 [==============================] - 0s 2ms/step - loss: 16.1813 - r_square: 0.7871 - val_loss: 18.3797 - val_r_square: 0.7963
# Epoch 39/100
# 9/9 [==============================] - 0s 2ms/step - loss: 14.1908 - r_square: 0.8123 - val_loss: 14.2330 - val_r_square: 0.8304
# Epoch 40/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.7509 - r_square: 0.8279 - val_loss: 14.8071 - val_r_square: 0.8308
# Epoch 41/100
# 9/9 [==============================] - 0s 2ms/step - loss: 14.7503 - r_square: 0.8054 - val_loss: 15.8238 - val_r_square: 0.8260
# Epoch 42/100
# 9/9 [==============================] - 0s 2ms/step - loss: 15.6929 - r_square: 0.7938 - val_loss: 18.3748 - val_r_square: 0.7768
# Epoch 43/100
# 9/9 [==============================] - 0s 2ms/step - loss: 15.5125 - r_square: 0.7795 - val_loss: 15.4522 - val_r_square: 0.8173
# Epoch 44/100
# 9/9 [==============================] - 0s 2ms/step - loss: 15.9466 - r_square: 0.8025 - val_loss: 14.2803 - val_r_square: 0.8333
# Epoch 45/100
# 9/9 [==============================] - 0s 2ms/step - loss: 17.2916 - r_square: 0.7806 - val_loss: 23.0327 - val_r_square: 0.7304
# Epoch 46/100
# 9/9 [==============================] - 0s 2ms/step - loss: 14.1897 - r_square: 0.7874 - val_loss: 13.9069 - val_r_square: 0.8366
# Epoch 47/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.3016 - r_square: 0.8177 - val_loss: 14.1675 - val_r_square: 0.8381
# Epoch 48/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.8137 - r_square: 0.8328 - val_loss: 13.6356 - val_r_square: 0.8203
# Epoch 49/100
# 9/9 [==============================] - 0s 2ms/step - loss: 17.6977 - r_square: 0.7430 - val_loss: 13.9742 - val_r_square: 0.8168
# Epoch 50/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.7406 - r_square: 0.8598 - val_loss: 19.6904 - val_r_square: 0.7750
# Epoch 51/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.2643 - r_square: 0.8418 - val_loss: 14.4411 - val_r_square: 0.8228
# Epoch 52/100
# 9/9 [==============================] - 0s 2ms/step - loss: 17.7157 - r_square: 0.7666 - val_loss: 14.0994 - val_r_square: 0.8355
# Epoch 53/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.1176 - r_square: 0.8304 - val_loss: 13.1379 - val_r_square: 0.8481
# Epoch 54/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.1475 - r_square: 0.8439 - val_loss: 14.2539 - val_r_square: 0.8237
# Epoch 55/100
# 9/9 [==============================] - 0s 2ms/step - loss: 13.5900 - r_square: 0.8158 - val_loss: 19.5408 - val_r_square: 0.7784
# Epoch 56/100
# 9/9 [==============================] - 0s 2ms/step - loss: 18.1329 - r_square: 0.7461 - val_loss: 15.1909 - val_r_square: 0.8333
# Epoch 57/100
# 9/9 [==============================] - 0s 2ms/step - loss: 13.2879 - r_square: 0.8167 - val_loss: 19.9319 - val_r_square: 0.7752
# Epoch 58/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.5580 - r_square: 0.8005 - val_loss: 14.8017 - val_r_square: 0.8168
# Epoch 59/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.9071 - r_square: 0.8511 - val_loss: 15.8659 - val_r_square: 0.8227
# Epoch 60/100
# 9/9 [==============================] - 0s 2ms/step - loss: 14.1278 - r_square: 0.7966 - val_loss: 15.5193 - val_r_square: 0.8066
# Epoch 61/100
# 9/9 [==============================] - 0s 2ms/step - loss: 13.6123 - r_square: 0.8184 - val_loss: 15.8828 - val_r_square: 0.8129
# Epoch 62/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.7906 - r_square: 0.8463 - val_loss: 18.0200 - val_r_square: 0.7907
# Epoch 63/100
# 9/9 [==============================] - 0s 3ms/step - loss: 13.0182 - r_square: 0.8386 - val_loss: 17.4679 - val_r_square: 0.8064
# Epoch 64/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.3458 - r_square: 0.8467 - val_loss: 12.7114 - val_r_square: 0.8415
# Epoch 65/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.4001 - r_square: 0.8234 - val_loss: 14.5051 - val_r_square: 0.8289
# Epoch 66/100
# 9/9 [==============================] - 0s 2ms/step - loss: 12.1259 - r_square: 0.8287 - val_loss: 14.2236 - val_r_square: 0.8351
# Epoch 67/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.8667 - r_square: 0.8616 - val_loss: 12.7731 - val_r_square: 0.8421
# Epoch 68/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.7694 - r_square: 0.8592 - val_loss: 15.6830 - val_r_square: 0.7994
# Epoch 69/100
# 9/9 [==============================] - 0s 2ms/step - loss: 9.9544 - r_square: 0.8666 - val_loss: 12.8628 - val_r_square: 0.8433
# Epoch 70/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.4844 - r_square: 0.8368 - val_loss: 14.9569 - val_r_square: 0.8310
# Epoch 71/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.4441 - r_square: 0.8490 - val_loss: 12.6873 - val_r_square: 0.8340
# Epoch 72/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.0769 - r_square: 0.8720 - val_loss: 13.7271 - val_r_square: 0.8436
# Epoch 73/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.0333 - r_square: 0.8525 - val_loss: 13.8505 - val_r_square: 0.8405
# Epoch 74/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.6317 - r_square: 0.8618 - val_loss: 12.8500 - val_r_square: 0.8487
# Epoch 75/100
# 9/9 [==============================] - 0s 2ms/step - loss: 13.6243 - r_square: 0.8152 - val_loss: 14.8169 - val_r_square: 0.8291
# Epoch 76/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.4542 - r_square: 0.8578 - val_loss: 18.3823 - val_r_square: 0.7898
# Epoch 77/100
# 9/9 [==============================] - 0s 2ms/step - loss: 9.9281 - r_square: 0.8777 - val_loss: 18.9110 - val_r_square: 0.7647
# Epoch 78/100
# 9/9 [==============================] - 0s 2ms/step - loss: 14.6708 - r_square: 0.7803 - val_loss: 14.5017 - val_r_square: 0.8336
# Epoch 79/100
# 9/9 [==============================] - 0s 2ms/step - loss: 9.6142 - r_square: 0.8702 - val_loss: 14.5046 - val_r_square: 0.8328
# Epoch 80/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.3449 - r_square: 0.8501 - val_loss: 12.3532 - val_r_square: 0.8439
# Epoch 81/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.4630 - r_square: 0.8683 - val_loss: 12.9353 - val_r_square: 0.8379
# Epoch 82/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.3996 - r_square: 0.8492 - val_loss: 13.5454 - val_r_square: 0.8413
# Epoch 83/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.6479 - r_square: 0.8385 - val_loss: 12.4529 - val_r_square: 0.8483
# Epoch 84/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.1879 - r_square: 0.8665 - val_loss: 12.9118 - val_r_square: 0.8468
# Epoch 85/100
# 9/9 [==============================] - 0s 3ms/step - loss: 10.6153 - r_square: 0.8523 - val_loss: 12.0005 - val_r_square: 0.8485
# Epoch 86/100
# 9/9 [==============================] - 0s 3ms/step - loss: 12.3758 - r_square: 0.8388 - val_loss: 14.4554 - val_r_square: 0.8228
# Epoch 87/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.4161 - r_square: 0.8483 - val_loss: 15.4526 - val_r_square: 0.8175
# Epoch 88/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.1344 - r_square: 0.8609 - val_loss: 16.8050 - val_r_square: 0.8007
# Epoch 89/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.0116 - r_square: 0.8386 - val_loss: 14.6508 - val_r_square: 0.8240
# Epoch 90/100
# 9/9 [==============================] - 0s 2ms/step - loss: 9.4317 - r_square: 0.8753 - val_loss: 13.2625 - val_r_square: 0.8405
# Epoch 91/100
# 9/9 [==============================] - 0s 3ms/step - loss: 9.7710 - r_square: 0.8696 - val_loss: 13.8891 - val_r_square: 0.8329
# Epoch 92/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.3409 - r_square: 0.8687 - val_loss: 12.5190 - val_r_square: 0.8539
# Epoch 93/100
# 9/9 [==============================] - 0s 2ms/step - loss: 9.0322 - r_square: 0.8846 - val_loss: 13.5237 - val_r_square: 0.8430
# Epoch 94/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.0300 - r_square: 0.8500 - val_loss: 13.3157 - val_r_square: 0.8367
# Epoch 95/100
# 9/9 [==============================] - 0s 2ms/step - loss: 10.0886 - r_square: 0.8594 - val_loss: 15.7061 - val_r_square: 0.8089
# Epoch 96/100
# 9/9 [==============================] - 0s 2ms/step - loss: 13.5911 - r_square: 0.8126 - val_loss: 13.7382 - val_r_square: 0.8402
# Epoch 97/100
# 9/9 [==============================] - 0s 2ms/step - loss: 11.4400 - r_square: 0.8408 - val_loss: 13.7693 - val_r_square: 0.8399
# Epoch 98/100
# 9/9 [==============================] - 0s 2ms/step - loss: 9.4776 - r_square: 0.8726 - val_loss: 12.9995 - val_r_square: 0.8421
# Epoch 99/100
# 9/9 [==============================] - 0s 2ms/step - loss: 8.8056 - r_square: 0.8782 - val_loss: 11.9143 - val_r_square: 0.8491
# Epoch 100/100
# 9/9 [==============================] - 0s 2ms/step - loss: 8.8896 - r_square: 0.8804 - val_loss: 12.3929 - val_r_square: 0.8515

# %%
#Loss v/s epochs plot
loss = model.history['loss']
val_loss = model.history['val_loss']
epochs = range(1,len(loss)+1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='validation loss')
plt.legend( loc ='best')
plt.show()

# %%
#R_square v/s epochs plot
r_square = model.history['r_square']
val_r_square = model.history['val_r_square']
epochs = range(1,len(loss)+1)
plt.plot(epochs, r_square, 'y', label='Training r_square')
plt.plot(epochs, val_r_square, 'r', label='validation r_square')
plt.legend(loc ='best')
plt.show()

# %%
#Predictions on input test and train
y_predtest = model.model.predict(X_test)
y_predtrain = model.model.predict(X_train)
# Out:
# 5/5 [==============================] - 0s 964us/step
# 12/12 [==============================] - 0s 645us/step

# %%
#A scatter plot with a metric r_square
plt.figure(figsize = (8,8))
plt.plot([0,60],[0,60],color='black')
plt.scatter(y_test,y_predtest , s=35, color='red',marker='>',label='Test $R^{2}$=''%.3f'%r2_score(y_test,y_predtest),alpha=1)
plt.scatter(y_train, y_predtrain,    s=35, color='blue',marker='o',label='Train $R^{2}$=''%.3f'%r2_score(y_train,y_predtrain),alpha=1 )

plt.xlim(0,60)
plt.ylim(0,60)
plt.legend(frameon=False,prop={'weight':'bold'})
plt.xlabel('Measured MEDV',fontweight='bold')
plt.ylabel('Predicted MEDV',fontweight='bold')
plt.title('MLP Regression',fontweight='bold')
plt.axis('square')

#plt.savefig('NN.pdf', dpi=5000)   # Save the plot in pdf
plt.show()

# %%
#Conversion of array to list
def ndarray_series(y_predtest):
    list1 = []
    for i in y_predtest:
        list1.append(i[0])
    return list1

# %%
y_predtrain =  ndarray_series(y_predtrain)
y_predtest =  ndarray_series(y_predtest)

# %%
#Some important metrics for our trained model for train and test set
print('parameter for train')
print('mean_squared_error:', mean_squared_error(y_train,y_predtrain))
print('mean_absolute_error:',mean_absolute_error(y_train,y_predtrain))
print('root mean squared error:', sqrt(mean_squared_error(y_train,y_predtrain)))
print('MPAE:',np.mean(np.abs((y_train - y_predtrain) / y_train)) * 100)
print('\nR2 value_train:',r2_score(y_train,y_predtrain))

print('\nparameter for testing')
print('mean_squared_error:', mean_squared_error(y_test,y_predtest))
print('mean_absolute_error:',mean_absolute_error(y_test,y_predtest))
print('root mean squared error:', sqrt(mean_squared_error(y_test,y_predtest)))
print('MPAE:',np.mean(np.abs((y_test - y_predtest) / y_test)) * 100)
print('\nR2 value_test:',r2_score(y_test,y_predtest))
# Out:
# parameter for train
# mean_squared_error: 5.700732192234939
# mean_absolute_error: 1.6149619913370594
# root mean squared error: 2.387620613128254
# MPAE: 8.309083616084186
#
# R2 value_train: 0.9297844812568676
#
# parameter for testing
# mean_squared_error: 8.130841583033623
# mean_absolute_error: 2.1991116134743947
# root mean squared error: 2.851463060085756
# MPAE: 11.26036170460036
#
# R2 value_test: 0.9112881230353436
